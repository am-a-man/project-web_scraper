# %%
import os
import selenium
from selenium import webdriver
import time
from PIL import Image
import io
import requests
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import ElementClickInterceptedException

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\Aman\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache

# %%
os.environ['WDM_LOG_LEVEL'] = '0'

# %%
search_url='https://careers.microsoft.com/students/us/en/search-results'
driver.get(search_url)

# %% [markdown]
# Select the region you want to extract data from:

# %%
touch = selenium.webdriver.common.touch_actions.TouchActions(driver)

# %%
touch.tap(driver.find_element_by_class_name('au-target.icon.icon-down-arrow'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e91ecfc574f5> in <module>
# ----> 1 touch.tap(driver.find_element_by_class_name('au-target.icon.icon-down-arrow')).text
#
# AttributeError: 'TouchActions' object has no attribute 'text'

# %%
driver.title
# Out:
# 'Search results | Find available job openings at Microsoft'

# %%
main = driver.find_element_by_css_selector('body')
print(main.text)
# Out:
# We use cookies to improve your experience on our websites and for advertising. Privacy Statement Manage cookies Accept all
# Skip to main content
# Microsoft 365
# Office
# Windows
# Surface
# Xbox
# Deals
# Support
# Careers
# Professionals
# Students and graduates
# Life at Microsoft
# Sign in
# Saved jobs
# -
# Search results
# Find jobs
# Learn more
# Skip to Show Results
# Refine your search
# Country/Region
# State/Province
# City
# Profession
# Discipline
# Employment type
# Level of education
# Get personalized job recommendations
# Sign in or create a profile and we'll let you know when there's a match.
# Sign in
# Showing 1 -
# to
# 20 of 248 jobs
# Sort by
#                                     Most relevant
#                                     Most recent
#                                     Most popular
#                                  2021 Graduates-Associate Researcher/Researcher-MSRA-Shanghai
# Shanghai, Shanghai, China
# Research
# Aug 12, 2020
# ...

# %%
#driver.find_element_by_xpath("//button[@aria-label='toggle refine search']").click()

# %%
driver.find_element_by_xpath("//button[@aria-label='Country/Region']").click()

# %%
#  inputElement = driver.find_element_by_xpath("//input[@aria-label='Search in country/region']")
#  inputElement.send_keys('India')

# %%
text = driver.find_element_by_xpath("//ul[@data-ph-at-id='jobs-list']")
listItems = text.find_elements_by_tag_name('li')
for items in listItems:
    print('========================')
    print(items.text)
    print('========================')
# Out:
# ...
# Research Intern
# Bangalore, Karnataka, India
# Research
# Jan 18, 2021
# Interns put inquiry and theory into practice. Working with some of the world’s best researchers, interns learn, collaborate, and network for life. Interns not only advance their own careers, but
# Save
# ...
# Post Doc Researcher
# Bangalore, Karnataka, India
# Research
# Jul 15, 2020
# The Microsoft Research India Post-doctoral Researcher program brings together fresh PhDs from all over the world with our researchers. It provides the post-doctoral researchers the opportunity to work
# Save
# ...
# SCAI Centre Fellow
# Bangalore, Karnataka, India
# Research
# Jan 22, 2020
# Microsoft Research India invites applications for its AI Centre Postdoctoral Fellows Program.Candidates who have completed their PhDs are eligible to apply. Submit your application now for early
# Save
# ...

# %%
main = driver.find_element_by_css_selector('body')
print(main.text)
# Out:
# We use cookies to improve your experience on our websites and for advertising. Privacy Statement Manage cookies Accept all
# Skip to main content
# Microsoft 365
# Office
# Windows
# Surface
# Xbox
# Deals
# Support
# Careers
# Professionals
# Students and graduates
# Life at Microsoft
# Sign in
# Saved jobs
# -
# Search results
# Find jobs
# Learn more
# Skip to Show Results
# Refine your search
# Country/Region
# Search incountry
# United States (129)
# jobs
# China (54)
# jobs
# United Kingdom (23)
# jobs
# Canada (11)
# jobs
# Taiwan (10)
# jobs
# Israel (7)
# jobs
# Japan (6)
# jobs
# India (3)
# jobs
# France (2)
# jobs
# Germany (1)
# job
# Russia (1)
# job
# Saudi Arabia (1)
# job
# South Africa (1)
# job
# Turkey (1)
# job
# United Arab Emirates (1)
# job
# State/Province
# City
# Profession
# Discipline
# Employment type
# Level of education
# Get personalized job recommendations
# Sign in or create a profile and we'll let you know when there's a match.
# Sign in
# ...
